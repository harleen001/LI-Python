# %%
 # %pip install snakeviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %load_ext snakeviz

# %%
def sum(a,b):
    a=a+b
    b=a-b
    a=a+b

# %%
# %%snakeviz
# sum(10,20)
# Out:
#
# *** Profile stats marshalled to file 'C:\\Users\\hp\\AppData\\Local\\Temp\\tmpdh47kenx'.
# Embedding SnakeViz in this document...
# <function display at 0x0000023069BE62A0>
# <iframe id='snakeviz-5342c6eb-ec6b-11f0-8c14-3003c84539fa' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-5342c6eb-ec6b-11f0-8c14-3003c84539fa").setAttribute("src", "http://" + document.location.hostname + ":8080/snakeviz/C%3A%5CUsers%5Chp%5CAppData%5CLocal%5CTemp%5Ctmpdh47kenx")</script>

# %%
def abc(a,b):
    a=a^b
    b=a^b
    a=a^b

# %%
# %%snakeviz
# sum(10,20)
# Out:
#
# *** Profile stats marshalled to file 'C:\\Users\\hp\\AppData\\Local\\Temp\\tmpngosor4y'.
# Embedding SnakeViz in this document...
# <function display at 0x0000023069BE62A0>
# <iframe id='snakeviz-7cb86986-ec6b-11f0-9993-3003c84539fa' frameborder=0 seamless width='100%' height='1000'></iframe>
# <script>document.getElementById("snakeviz-7cb86986-ec6b-11f0-9993-3003c84539fa").setAttribute("src", "http://" + document.location.hostname + ":8080/snakeviz/C%3A%5CUsers%5Chp%5CAppData%5CLocal%5CTemp%5Ctmpngosor4y")</script>
