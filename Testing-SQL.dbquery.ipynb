-- %%
create database students;
use students;
CREATE TABLE stu (
    id INT PRIMARY KEY,
    name VARCHAR(50) NOT NULL,
    age INT
);

INSERT INTO stu (id, name, age) 
VALUES 
    (1, 'Alice', 20),
    (2, 'Bob', 22),
    (3, 'Charlie', 21),
    (4, 'Diana', 19),
    (5, 'Eve', 23); 

    select * from stu;  

    drop table students;
