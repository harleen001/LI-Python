# %%
df=spark.table("workspace.default.movies")
display(df)

# %%
df.printSchema()

# %%
df.count()

# %%
df.describe().show()

# %%
df.columns

# %%
display(df.describe())

# %%
### only display few columns

df_trimmed=df.select("title","imdb_rating","release_year")
df_trimmed.show(3,truncate=False)   #showing only 3 columns

# %%
display(df.filter((df.release_year >= 2000) & (df.release_year <= 2010)))

# %%
from pyspark.sql.functions import col
df_marvel=df.filter(col("studio")=='Marvel Studios')
df_marvel.show()

# %%
unique_industries=df.select("industry").distinct()
display(unique_industries)

# %%
unique_language=df.select("language").distinct()
display(unique_language)
